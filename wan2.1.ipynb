# %% [markdown]
# <a href="https://colab.research.google.com/github/ROCKMOHAN/ASNE/blob/master/wan2.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Wan-Video/Wan2.1.git
# !cd Wan2.1
# Out:
# Cloning into 'Wan2.1'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 92 (delta 14), reused 5 (delta 5), pack-reused 71 (from 2)
# Receiving objects: 100% (92/92), 5.74 MiB | 6.20 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# !ls
# Out:
# sample_data  Wan2.1

# %%
# !cd ./Wan2.1

# %%
# !pip install "huggingface_hub[cli]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.4 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli download "Wan-AI/Wan2.1-T2V-1.3B" --local-dir "./Wan2.1-T2V-1.3B"
# Out:
# Fetching 22 files:   0% 0/22 [00:00<?, ?it/s]Downloading 'assets/data_for_diff_stage.jpg' to 'Wan2.1-T2V-1.3B/.cache/huggingface/download/assets/UCVN8O248kjCIp8i1TvUXWfm-q4=.59aec08409f2d46b0e640e4e120dc7cca52c08c3de56d026602dbcff1ebf241a.incomplete'
# ...
#
# comp_effic.png:   0% 0.00/1.79M [00:00<?, ?B/s]Downloading '.gitattributes' to 'Wan2.1-T2V-1.3B/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.0a1f66aea84e17cbf6a60c51431723062f87df8a.incomplete'
# ...
# comp_effic.png: 100% 1.79M/1.79M [00:00<00:00, 76.5MB/s]
# Download complete. Moving file to Wan2.1-T2V-1.3B/assets/comp_effic.png
#
# data_for_diff_stage.jpg:   0% 0.00/528k [00:00<?, ?B/s]
#
# .DS_Store: 100% 6.15k/6.15k [00:00<00:00, 29.4MB/s]
# Download complete. Moving file to Wan2.1-T2V-1.3B/assets/.DS_Store
#
#
# i2v_res.png:   0% 0.00/892k [00:00<?, ?B/s]
#
#
# data_for_diff_stage.jpg: 100% 528k/528k [00:00<00:00, 32.8MB/s]
# Download complete. Moving file to Wan2.1-T2V-1.3B/assets/data_for_diff_stage.jpg
# ...

# %%
# !pip install -r ./Wan2.1/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 84.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...

# %%
# !python ./Wan2.1/generate.py  --task t2v-1.3B --size "832*480" --ckpt_dir ./Wan2.1-T2V-1.3B --offload_model True --t5_cpu --sample_shift 8 --sample_guide_scale 6 --prompt "Two anthropomorphic cats in comfy boxing gear and bright gloves fight intensely on a spotlighted stage."
# Out:
# [2025-03-02 15:26:01,777] INFO: offload_model is not specified, set to True.
# [2025-03-02 15:26:01,777] INFO: Generation job args: Namespace(task='t2v-1.3B', size='832*480', frame_num=81, ckpt_dir='./Wan2.1-T2V-1.3B', offload_model=True, ulysses_size=1, ring_size=1, t5_fsdp=False, t5_cpu=False, dit_fsdp=False, save_file=None, prompt='Two anthropomorphic cats in comfy boxing gear and bright gloves fight intensely on a spotlighted stage.', use_prompt_extend=False, prompt_extend_method='local_qwen', prompt_extend_model=None, prompt_extend_target_lang='ch', base_seed=259085795484544898, image=None, sample_solver='unipc', sample_steps=50, sample_shift=8.0, sample_guide_scale=6.0)
# ...

# %%
from IPython.display import Video
